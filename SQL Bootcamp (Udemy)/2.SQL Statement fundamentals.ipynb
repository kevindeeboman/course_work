# %%
import psycopg2 as pg2
import pandas as pd

# %%
conn = pg2.connect(database='dvdrental', user='kevindeeboman')
cur = conn.cursor()

# %%
def show_res(cur, head=False):
    res = cur.fetchall()
    col_names = [desc[0] for desc in cur.description]
    df = pd.DataFrame(data= res, columns=col_names)
    if head == True:
        display(df.head(3))
    else:
        display(df)

# %%
# Select statements # SQL syntax is written i captial letters! #
cur.execute("""
    SELECT * FROM film;
    """)
show_res(cur, head=True)

# * references all columns, but we can also pick which cols we want! #
cur.execute("""
    SELECT first_name, last_name, email FROM customer;
    """)
show_res(cur, head=True)
# Out:
#    film_id             title  \
# 0      133   Chamber Italian
# 1      384  Grosse Wonderful
# 2        8   Airport Pollock
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
# 2  A Epic Tale of a Moose And a Girl who must Con...          2006
#
#    language_id  rental_duration rental_rate  length replacement_cost rating  \
# 0            1                7        4.99     117            14.99  NC-17
# 1            1                5        4.99      49            19.99      R
# 2            1                6        4.99      54            15.99      R
#
#               last_update     special_features  \
# 0 2013-05-26 14:50:58.951           [Trailers]
# 1 2013-05-26 14:50:58.951  [Behind the Scenes]
# 2 2013-05-26 14:50:58.951           [Trailers]
#
#                                             fulltext
# 0  'chamber':1 'fate':4 'husband':11 'italian':2 ...
# 1  'australia':18 'cat':8 'drama':5 'epic':4 'exp...
# 2  'airport':1 'ancient':18 'confront':14 'epic':...
#   first_name last_name                                email
# 0      Jared       Ely         jared.ely@sakilacustomer.org
# 1       Mary     Smith        mary.smith@sakilacustomer.org
# 2   Patricia   Johnson  patricia.johnson@sakilacustomer.org

# %%
# Aggregate functions - Distinct # Distinct show unique values for a column #
cur.execute("""
    SELECT DISTINCT(rating) FROM film;
    """)
show_res(cur)

# Aggregate functions can also be used together #
cur.execute("""
    SELECT COUNT(DISTINCT(rating)) FROM film;
    """)
show_res(cur)
# We find that there are 5 unique movie ratings #
# Out:
#   rating
# 0      R
# 1     PG
# 2  PG-13
# 3  NC-17
# 4      G
#    count
# 0      5

# %%
# WHERE statement # Conditions for queries # WHERE can be combine with Logical operators --> AND, OR, NOT #
cur.execute("""
    SELECT title, rating, length, rental_rate FROM film
    WHERE rating = 'R' AND rental_rate < 4.99 AND NOT length < 175
    ;
    """)
show_res(cur, head=True)
# Here we filter out all R-rated films that have a rental rate lower than 4.99 which are not shorter than 175 min #
# Out:
#               title rating  length rental_rate
# 0  Analyze Hoosiers      R     181        2.99
# 1        Cause Date      R     179        2.99
# 2      Double Wrath      R     177        0.99

# %%
# ORDER BY # Sort values by specification # Most commonly by ASC (ascending order) or DESC (descending order) #
# Below we see that we are sorting by store_id by descending order and first_name by ascending order #
cur.execute("""
    SELECT store_id, first_name, last_name FROM customer
    ORDER BY store_id DESC, first_name ASC
    ;
    """)
show_res(cur, head=True)
# NOTE -> Sorting should be performed last, selection and filtering should be performed first #
# Out:
#    store_id first_name last_name
# 0         2      Aaron     Selby
# 1         2     Adrian     Clary
# 2         2      Agnes    Bishop

# %%
# LIMIT # Simply limits the number of returned results #
cur.execute("""
    SELECT store_id, first_name, last_name FROM customer
    ORDER BY store_id DESC, first_name ASC
    LIMIT 10
    ;
    """)
show_res(cur)
# LIMIT should ALWAYS be stated LAST #
# Out:
#    store_id first_name    last_name
# 0         2      Aaron        Selby
# 1         2     Adrian        Clary
# 2         2      Agnes       Bishop
# 3         2    Alberto      Henning
# 4         2       Alex      Gresham
# 5         2  Alexander      Fennell
# 6         2     Alfred     Casillas
# 7         2    Alfredo      Mcadams
# 8         2      Allen  Butterfield
# 9         2    Allison      Stanley

# %%
# ORDER BY w. LIMIT # Here we show the latest 5 payments and the total amount spent #
cur.execute("""
    SELECT * FROM payment
    WHERE amount <> 0.00
    ORDER BY payment_date DESC
    LIMIT 5
    ;
    """)
show_res(cur)
# Similarly we can explore the top 5 shortest films #
cur.execute("""
    SELECT title, length FROM film
    ORDER BY length ASC
    LIMIT 5
    ;
    """)
show_res(cur)
# How many films have a length of 50 min or less? #
cur.execute("""
    SELECT COUNT(*) FROM film
    WHERE length <= 50
    ;
    """)
show_res(cur)
# Out:
#    payment_id  customer_id  staff_id  rental_id amount  \
# 0       31922          279         2      13538   4.99
# 1       31917          267         2      12066   7.98
# 2       31919          269         1      13025   3.98
# 3       31921          274         1      13486   0.99
# 4       31923          282         2      15430   0.99
#
#                 payment_date
# 0 2007-05-14 13:44:29.996577
# 1 2007-05-14 13:44:29.996577
# 2 2007-05-14 13:44:29.996577
# 3 2007-05-14 13:44:29.996577
# 4 2007-05-14 13:44:29.996577
#                  title  length
# 0     Labyrinth League      46
# 1         Alien Center      46
# 2            Iron Moon      46
# 3        Kwai Homeward      46
# 4  Ridgemont Submarine      46
#    count
# 0     37

# %%
# BETWEEN operator # 
# value BETWEEN low AND high == value >= low AND value <= high # BETWEEN IS INCLUSIVE #
# We can also use -> value NOT BETWEEN low AND high == value < low AND value > high # NOT BETWEEN IS EXCLUSIVE #
cur.execute("""
    SELECT * FROM payment
    WHERE payment_date BETWEEN '2007-02-01' AND '2007-02-15'
    ;
    """)
show_res(cur, head=True)
# Out:
#    payment_id  customer_id  staff_id  rental_id amount  \
# 0       17610          368         1       1186   0.99
# 1       17617          370         2       1190   6.99
# 2       17743          402         2       1194   4.99
#
#                 payment_date
# 0 2007-02-14 23:25:11.996577
# 1 2007-02-14 23:33:58.996577
# 2 2007-02-14 23:53:34.996577

# %%
# IN operator # To check for multiple conditions/values we use IN #
# This could also be done using WHERE together with OR statements #
cur.execute("""
    SELECT * FROM film_list
    WHERE category IN ('Horror', 'Comedy')
    ;
    """)
show_res(cur, head=True)
# Similarly, we can do the opposite #
cur.execute("""
    SELECT * FROM film_list
    WHERE category NOT IN ('Horror', 'Comedy')
    ;
    """)
show_res(cur, head=True)
# Out:
#    fid              title                                        description  \
# 0  308      Ferris Mother  A Touching Display of a Frisbee And a Frisbee ...
# 1  857  Strictly Scarface  A Touching Reflection of a Crocodile And a Dog...
# 2  494        Karate Moon  A Astounding Yarn of a Womanizer And a Dog who...
#
#   category price  length rating  \
# 0   Comedy  2.99     142     PG
# 1   Comedy  2.99     144  PG-13
# 2   Horror  0.99     120  PG-13
#
#                                               actors
# 0                                     Sissy Sobieski
# 1  Greg Chaplin, Daryl Crawford, Whoopi Hurt, Ala...
# 2  Johnny Cage, Susan Davis, Julianne Dench, Jane...
#    fid                title  \
# 0  730  Ridgemont Submarine
# 1  892     Titanic Boondock
# 2  286        Enough Raging
#
#                                          description   category price  length  \
# 0  A Unbelieveable Drama of a Waitress And a Comp...        New  0.99      46
# 1  A Brilliant Reflection of a Feminist And a Dog...  Animation  4.99     104
# 2  A Astounding Character Study of a Boat And a S...     Travel  2.99     158
#
#   rating                                             actors
# 0  PG-13  Johnny Lollobrigida, Julianne Dench, Whoopi Hu...
# 1      R  Bette Nicholson, Dan Harris, Penelope Cronyn, ...
# 2  NC-17  Johnny Lollobrigida, Sandra Peck, Sean William...

# %%
# LIKE (CASE SENSITIVE) and ILIKE (NOT CASE SENSITIVE) # Pattern matching using wildcard characters % and _ #
# % == Matches any sequence of characters # _ == matches any single character #
# Here we find all names where the second/third character is "oh" #
# The first char is one random -> _ # After h, an unspecified number of random chars may be present #
cur.execute("""
    SELECT first_name FROM customer
    WHERE first_name ILIKE '_oh%'
    ;
    """)
show_res(cur)

cur.execute("""
    SELECT * FROM film_list
    WHERE description ILIKE '%sql%'
    ;
    """)
show_res(cur, head=True)
# SQL fully supports Regex, google that shit if needed #
# Out:
#   first_name
# 0       John
# 1     Johnny
# 2    Johnnie
#    fid               title                                        description  \
# 0  907  Translation Summer  A Touching Reflection of a Man And a Monkey wh...
# 1  494         Karate Moon  A Astounding Yarn of a Womanizer And a Dog who...
# 2  918     Twisted Pirates  A Touching Display of a Frisbee And a Boat who...
#
#    category price  length rating  \
# 0     Drama  0.99     168  PG-13
# 1    Horror  0.99     120  PG-13
# 2  Children  4.99     152     PG
#
#                                               actors
# 0           Tom Miranda, Laura Brody, Matthew Carrey
# 1  Johnny Cage, Susan Davis, Julianne Dench, Jane...
# 2           Natalie Hopkins, Jude Cruise, Adam Grant
